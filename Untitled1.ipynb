# %% [markdown]
# <a href="https://colab.research.google.com/github/RoNiN-shadow/testLunarAIforColab/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# cmake is already the newest version (3.16.3-1ubuntu1.20.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 15 not upgraded.
# Need to get 1,086 kB of archives.
# After this operation, 5,413 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig4.0 amd64 4.0.1-5build1 [1,081 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 swig all 4.0.1-5build1 [5,528 B]
# Fetched 1,086 kB in 0s (8,222 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 123071 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.1-5build1_amd64.deb ...
# Unpacking swig4.0 (4.0.1-5build1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.1-5build1_all.deb ...
# Unpacking swig (4.0.1-5build1) ...
# Setting up swig4.0 (4.0.1-5build1) ...
# Setting up swig (4.0.1-5build1) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
# Collecting stable-baselines3==2.0.0a5 (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1))
#   Using cached stable_baselines3-2.0.0a5-py3-none-any.whl (177 kB)
# Collecting gymnasium[box2d] (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Using cached gymnasium-0.28.1-py3-none-any.whl (925 kB)
# Collecting huggingface_sb3 (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3))
#   Using cached huggingface_sb3-2.2.5-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.22.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.7.1)
# Collecting jax-jumpy>=1.0.0 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Using cached jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2)) (4.6.3)
# Collecting farama-notifications>=0.0.1 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Using cached box2d-py-2.3.5.tar.gz (374 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.3 (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Downloading pygame-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 94.6 MB/s eta 0:00:00
# Collecting swig==4.* (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2))
#   Downloading swig-4.1.1-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 87.6 MB/s eta 0:00:00
# Collecting huggingface-hub~=0.8 (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3))
#   Downloading huggingface_hub-0.16.2-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.5/268.5 kB 33.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (6.0)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.10/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.1.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.65.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (16.0.6)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (8.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2022.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.3.0)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp310-cp310-linux_x86_64.whl size=2783915 sha256=8bdb91538030b78f9e8a5ad8c1cc10580b28247609fef3ed666376cc4960cff7
#   Stored in directory: /root/.cache/pip/wheels/db/8f/6a/eaaadf056fba10a98d986f6dce954e6201ba3126926fc5ad9e
# Successfully built box2d-py
# Installing collected packages: swig, farama-notifications, box2d-py, pygame, jax-jumpy, huggingface-hub, gymnasium, huggingface_sb3, stable-baselines3
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.4.0
#     Uninstalling pygame-2.4.0:
#       Successfully uninstalled pygame-2.4.0
# Successfully installed box2d-py-2.3.5 farama-notifications-0.0.4 gymnasium-0.28.1 huggingface-hub-0.16.2 huggingface_sb3-2.2.5 jax-jumpy-1.0.0 pygame-2.1.3 stable-baselines3-2.0.0a5 swig-4.1.1

# %%
# !sudo apt-get update
# !apt install python-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease [3,622 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu focal InRelease
# Get:4 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease [18.1 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal-updates InRelease [114 kB]
# Hit:6 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Get:7 http://security.ubuntu.com/ubuntu focal-security InRelease [114 kB]
# Hit:8 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Get:9 http://archive.ubuntu.com/ubuntu focal-backports InRelease [108 kB]
# Get:10 http://archive.ubuntu.com/ubuntu focal-updates/multiverse amd64 Packages [40.3 kB]
# Get:11 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease [24.3 kB]
# Get:12 http://archive.ubuntu.com/ubuntu focal-updates/restricted amd64 Packages [2,664 kB]
# Get:13 http://security.ubuntu.com/ubuntu focal-security/main amd64 Packages [2,858 kB]
# Get:14 http://security.ubuntu.com/ubuntu focal-security/restricted amd64 Packages [2,482 kB]
# Get:15 http://security.ubuntu.com/ubuntu focal-security/universe amd64 Packages [1,069 kB]
# Get:16 http://security.ubuntu.com/ubuntu focal-security/multiverse amd64 Packages [28.5 kB]
# Hit:17 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Get:18 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 Packages [3,342 kB]
# Get:19 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main Sources [2,604 kB]
# Get:20 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 Packages [1,369 kB]
# Get:21 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal/main amd64 Packages [1,229 kB]
# Get:22 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal/main amd64 Packages [44.1 kB]
# Fetched 18.1 MB in 3s (7,195 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   freeglut3 libpython2-stdlib python2 python2-minimal
# Suggested packages:
#   python-tk python-numpy libgle3 python2-doc
# The following NEW packages will be installed:
#   freeglut3 libpython2-stdlib python-opengl python2 python2-minimal
# 0 upgraded, 5 newly installed, 0 to remove and 26 not upgraded.
# Need to get 621 kB of archives.
# After this operation, 6,059 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2-minimal amd64 2.7.17-2ubuntu4 [27.5 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libpython2-stdlib amd64 2.7.17-2ubuntu4 [7,072 B]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 python2 amd64 2.7.17-2ubuntu4 [26.5 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/universe amd64 freeglut3 amd64 2.8.1-3 [73.6 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/universe amd64 python-opengl all 3.1.0+dfsg-2build1 [486 kB]
# Fetched 621 kB in 0s (5,387 kB/s)
# Selecting previously unselected package python2-minimal.
# (Reading database ... 123822 files and directories currently installed.)
# Preparing to unpack .../python2-minimal_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package libpython2-stdlib:amd64.
# Preparing to unpack .../libpython2-stdlib_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2-minimal (2.7.17-2ubuntu4) ...
# Selecting previously unselected package python2.
# (Reading database ... 123851 files and directories currently installed.)
# Preparing to unpack .../python2_2.7.17-2ubuntu4_amd64.deb ...
# Unpacking python2 (2.7.17-2ubuntu4) ...
# Selecting previously unselected package freeglut3:amd64.
# Preparing to unpack .../freeglut3_2.8.1-3_amd64.deb ...
# Unpacking freeglut3:amd64 (2.8.1-3) ...
# Selecting previously unselected package python-opengl.
# Preparing to unpack .../python-opengl_3.1.0+dfsg-2build1_all.deb ...
# Unpacking python-opengl (3.1.0+dfsg-2build1) ...
# Setting up freeglut3:amd64 (2.8.1-3) ...
# Setting up libpython2-stdlib:amd64 (2.7.17-2ubuntu4) ...
# Setting up python2 (2.7.17-2ubuntu4) ...
# Setting up python-opengl (3.1.0+dfsg-2build1) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 26 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 26 not upgraded.
# Need to get 7,697 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/main amd64 libfontenc1 amd64 1:1.1.4-0ubuntu1 [14.0 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/main amd64 libxfont2 amd64 1:2.0.3-1 [91.7 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/main amd64 libxkbfile1 amd64 1:1.1.0-1 [65.3 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal/main amd64 x11-xkb-utils amd64 7.7+5 [158 kB]
# Get:5 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu1 [573 kB]
# Get:6 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-utils amd64 1:7.7+6 [91.5 kB]
# Get:7 http://archive.ubuntu.com/ubuntu focal/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 xserver-common all 2:1.20.13-1ubuntu1~20.04.8 [27.2 kB]
# Get:9 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 xvfb amd64 2:1.20.13-1ubuntu1~20.04.8 [780 kB]
# Fetched 7,697 kB in 0s (45.2 MB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 126241 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-0ubuntu1_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.3-1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.3-1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu1_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a1.20.13-1ubuntu1~20.04.8_all.deb ...
# Unpacking xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a1.20.13-1ubuntu1~20.04.8_amd64.deb ...
# Unpacking xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up libfontenc1:amd64 (1:1.1.4-0ubuntu1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu1) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1) ...
# Setting up libxfont2:amd64 (1:2.0.3-1) ...
# Setting up x11-xkb-utils (7.7+5) ...
# Setting up xfonts-utils (1:7.7+6) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:1.20.13-1ubuntu1~20.04.8) ...
# Setting up xvfb (2:1.20.13-1ubuntu1~20.04.8) ...
# Processing triggers for man-db (2.9.1-1) ...
# Processing triggers for fontconfig (2.13.1-2ubuntu3) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %%
import os

os.kill(os.getpid(), 9)

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %%
import gymnasium

from huggingface_sb3 import load_from_hub, package_to_hub
from huggingface_hub import (
    notebook_login,
)  # To log to our Hugging Face account to be able to upload models to the Hub.

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(
# /usr/local/lib/python3.10/dist-packages/jaxlib/xla_client.py:225: DeprecationWarning: ml_dtypes.float8_e4m3b11 is deprecated. Use ml_dtypes.float8_e4m3b11fnuz
#   float8_e4m3b11fnuz = ml_dtypes.float8_e4m3b11

# %%
import gymnasium as gym

# First, we create our environment called LunarLander-v2
env = gym.make("LunarLander-v2")

# Then we reset this environment
observation, info = env.reset()

for _ in range(20):
    # Take a random action
    action = env.action_space.sample()
    print("Action taken:", action)

    # Do this action in the environment and get
    # next_state, reward, terminated, truncated and info
    observation, reward, terminated, truncated, info = env.step(action)

    # If the game is terminated (in our case we land, crashed) or truncated (timeout)
    if terminated or truncated:
        # Reset the environment
        print("Environment is reset")
        observation, info = env.reset()

env.close()
# Out:
# Action taken: 2
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 2
# Action taken: 2
# Action taken: 1
# Action taken: 3
# Action taken: 2
# Action taken: 2
# Action taken: 0
# Action taken: 1
# Action taken: 3
# Action taken: 0
# Action taken: 1
# Action taken: 1
# Action taken: 0
# Action taken: 2
# Action taken: 1
# Action taken: 1

# %%
# We create our environment with gym.make("<name_of_the_environment>")
env = gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())  # Get a random observation
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-45.60477     13.721555     1.0744833    0.44635367   0.9205106
#    3.3818462    0.23485857   0.49047822]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())  # Take a random action
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Create the environment
env = make_vec_env("LunarLander-v2", n_envs=16)

# %%
# Create environment
env = gym.make('LunarLander-v2')

# Instantiate the agent
model = PPO('MlpPolicy', env, verbose=1)
# Train the agent
model.learn(total_timesteps=int(2e5))
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 102      |
# |    ep_rew_mean     | -242     |
# | time/              |          |
# |    fps             | 355      |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 99.6         |
# |    ep_rew_mean          | -240         |
# | time/                   |              |
# |    fps                  | 414          |
# |    iterations           | 2            |
# |    time_elapsed         | 9            |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0054875826 |
# |    clip_fraction        | 0.00259      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.000339    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 596          |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00429     |
# |    value_loss           | 2.23e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 96.6         |
# |    ep_rew_mean          | -222         |
# | time/                   |              |
# |    fps                  | 381          |
# |    iterations           | 3            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0064853914 |
# |    clip_fraction        | 0.0253       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.38        |
# |    explained_variance   | -0.0193      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 763          |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00439     |
# |    value_loss           | 1.92e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.9         |
# |    ep_rew_mean          | -193         |
# | time/                   |              |
# |    fps                  | 401          |
# |    iterations           | 4            |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0073814513 |
# |    clip_fraction        | 0.0379       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.37        |
# |    explained_variance   | -0.0128      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 429          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00494     |
# |    value_loss           | 1.14e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 94.7        |
# |    ep_rew_mean          | -187        |
# | time/                   |             |
# |    fps                  | 418         |
# |    iterations           | 5           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008803429 |
# |    clip_fraction        | 0.0593      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.000504   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 296         |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00874    |
# |    value_loss           | 548         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 93.5        |
# |    ep_rew_mean          | -165        |
# | time/                   |             |
# |    fps                  | 414         |
# |    iterations           | 6           |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.011257701 |
# |    clip_fraction        | 0.0437      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | 0.000215    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 282         |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.00756    |
# |    value_loss           | 719         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 93.3         |
# |    ep_rew_mean          | -142         |
# | time/                   |              |
# |    fps                  | 419          |
# |    iterations           | 7            |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0054928046 |
# |    clip_fraction        | 0.0436       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.34        |
# |    explained_variance   | -0.00249     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 193          |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00708     |
# |    value_loss           | 604          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 98          |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 8           |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.008710309 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | -8.33e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 110         |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 276         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 102         |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 9           |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.009895226 |
# |    clip_fraction        | 0.0667      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -0.000549   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 275         |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00895    |
# |    value_loss           | 417         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 428         |
# |    iterations           | 10          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.009806373 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | -0.00935    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 105         |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00837    |
# |    value_loss           | 210         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -104        |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 11          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.012223869 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.077       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 130         |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00963    |
# |    value_loss           | 324         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 123         |
# |    ep_rew_mean          | -90.7       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 12          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.008613347 |
# |    clip_fraction        | 0.0747      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.0493      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 152         |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00975    |
# |    value_loss           | 278         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 131         |
# |    ep_rew_mean          | -87.4       |
# | time/                   |             |
# |    fps                  | 433         |
# |    iterations           | 13          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.007172646 |
# |    clip_fraction        | 0.0321      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 0.0448      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 151         |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00621    |
# |    value_loss           | 349         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | -87.2       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 14          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.006450274 |
# |    clip_fraction        | 0.0394      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.0908      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 219         |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 441         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 164         |
# |    ep_rew_mean          | -85.1       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 15          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.009316228 |
# |    clip_fraction        | 0.045       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.9        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 148         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 175         |
# |    ep_rew_mean          | -82.8       |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 16          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008828707 |
# |    clip_fraction        | 0.0563      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.19        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.4        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.00627    |
# |    value_loss           | 128         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 194         |
# |    ep_rew_mean          | -82.2       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 17          |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.007888589 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 0.316       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.9        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00719    |
# |    value_loss           | 119         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 209          |
# |    ep_rew_mean          | -73.1        |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 18           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0056498256 |
# |    clip_fraction        | 0.0251       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.189        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 110          |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 351          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 222         |
# |    ep_rew_mean          | -72.9       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 19          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.007861955 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.416       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 93.4        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0058     |
# |    value_loss           | 137         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 233          |
# |    ep_rew_mean          | -71.2        |
# | time/                   |              |
# |    fps                  | 441          |
# |    iterations           | 20           |
# |    time_elapsed         | 92           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0054824073 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 246          |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00344     |
# |    value_loss           | 363          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 251         |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 21          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.010530532 |
# |    clip_fraction        | 0.0814      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.0895      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.9        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00962    |
# |    value_loss           | 146         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 260         |
# |    ep_rew_mean          | -65.9       |
# | time/                   |             |
# |    fps                  | 443         |
# |    iterations           | 22          |
# |    time_elapsed         | 101         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008455128 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.01       |
# |    explained_variance   | 0.336       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00608    |
# |    value_loss           | 191         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 278          |
# |    ep_rew_mean          | -65.6        |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 23           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0042004697 |
# |    clip_fraction        | 0.0208       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.01        |
# |    explained_variance   | 0.431        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 106          |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0051      |
# |    value_loss           | 160          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | -60.6       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 24          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010607941 |
# |    clip_fraction        | 0.07        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.218       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 89.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 152         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 312         |
# |    ep_rew_mean          | -59.2       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 25          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.007842596 |
# |    clip_fraction        | 0.0925      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.623       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.3        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00681    |
# |    value_loss           | 58.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 323        |
# |    ep_rew_mean          | -55.5      |
# | time/                   |            |
# |    fps                  | 444        |
# |    iterations           | 26         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.00824816 |
# |    clip_fraction        | 0.0977     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1         |
# |    explained_variance   | 0.407      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 33         |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0094    |
# |    value_loss           | 144        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 344         |
# |    ep_rew_mean          | -52.8       |
# | time/                   |             |
# |    fps                  | 446         |
# |    iterations           | 27          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.008466846 |
# |    clip_fraction        | 0.0854      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.958      |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 28.2        |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.006      |
# |    value_loss           | 61.6        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 359        |
# |    ep_rew_mean          | -49.5      |
# | time/                   |            |
# |    fps                  | 447        |
# |    iterations           | 28         |
# |    time_elapsed         | 128        |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01226023 |
# |    clip_fraction        | 0.0924     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.992     |
# |    explained_variance   | 0.723      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 12.5       |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.00761   |
# |    value_loss           | 61.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 369          |
# |    ep_rew_mean          | -47.7        |
# | time/                   |              |
# |    fps                  | 445          |
# |    iterations           | 29           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0069492552 |
# |    clip_fraction        | 0.0293       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.886       |
# |    explained_variance   | 0.34         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 76.3         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00403     |
# |    value_loss           | 133          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 387          |
# |    ep_rew_mean          | -45.2        |
# | time/                   |              |
# |    fps                  | 447          |
# |    iterations           | 30           |
# |    time_elapsed         | 137          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0067413514 |
# |    clip_fraction        | 0.048        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.918       |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.7         |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00811     |
# |    value_loss           | 67           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 402          |
# |    ep_rew_mean          | -40.4        |
# | time/                   |              |
# |    fps                  | 448          |
# |    iterations           | 31           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0066937446 |
# |    clip_fraction        | 0.0748       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.95        |
# |    explained_variance   | 0.548        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 66.3         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00661     |
# |    value_loss           | 183          |
# ------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c24a328a79e7> in <cell line: 7>()
#       5 model = PPO('MlpPolicy', env, verbose=1)
#       6 # Train the agent
# ----> 7 model.learn(total_timesteps=int(2e5))
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     306         progress_bar: bool = False,
#     307     ) -> SelfPPO:
# --> 308         return super().learn(
#     309             total_timesteps=total_timesteps,
#     310             callback=callback,
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     257
#     258         while self.num_timesteps < total_timesteps:
# --> 259             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     260
#     261             if continue_training is False:
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     176                 clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     177
# --> 178             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     179
#     180             self.num_timesteps += env.num_envs
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     169         """
#     170         self.step_async(actions)
# --> 171         return self.step_wait()
#     172
#     173     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/dummy_vec_env.py in step_wait(self)
#      55         # Avoid circular imports
#      56         for env_idx in range(self.num_envs):
# ---> 57             obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      58                 self.actions[env_idx]
#      59             )
#
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/monitor.py in step(self, action)
#      92         if self.needs_reset:
#      93             raise RuntimeError("Tried to step environment that needs reset")
# ---> 94         observation, reward, terminated, truncated, info = self.env.step(action)
#      95         self.rewards.append(float(reward))
#      96         if terminated or truncated:
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/time_limit.py in step(self, action)
#      55
#      56         """
# ---> 57         observation, reward, terminated, truncated, info = self.env.step(action)
#      58         self._elapsed_steps += 1
#      59
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/order_enforcing.py in step(self, action)
#      54         if not self._has_reset:
#      55             raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56         return self.env.step(action)
#      57
#      58     def reset(self, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/wrappers/env_checker.py in step(self, action)
#      47             return env_step_passive_checker(self.env, action)
#      48         else:
# ---> 49             return self.env.step(action)
#      50
#      51     def reset(self, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/box2d/lunar_lander.py in step(self, action)
#     535
#     536         # Generate two random numbers between -1/SCALE and 1/SCALE.
# --> 537         dispersion = [self.np_random.uniform(-1.0, +1.0) / SCALE for _ in range(2)]
#     538
#     539         m_power = 0.0
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/envs/box2d/lunar_lander.py in <listcomp>(.0)
#     535
#     536         # Generate two random numbers between -1/SCALE and 1/SCALE.
# --> 537         dispersion = [self.np_random.uniform(-1.0, +1.0) / SCALE for _ in range(2)]
#     538
#     539         m_power = 0.0
#
# /usr/local/lib/python3.10/dist-packages/gymnasium/core.py in np_random(self)
#     205             Instances of `np.random.Generator`
#     206         """
# --> 207         if self._np_random is None:
#     208             self._np_random, _ = seeding.np_random()
#     209         return self._np_random
#
# KeyboardInterrupt:

# %%
# SOLUTION
# We added some parameters to accelerate the training
model = PPO(
    policy="MlpPolicy",
    env=env,
    n_steps=1024,
    batch_size=64,
    n_epochs=4,
    gamma=0.999,
    gae_lambda=0.98,
    ent_coef=0.01,
    verbose=1,
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
# SOLUTION
# Train it for 1,000,000 timesteps
model.learn(total_timesteps=1000000)
# Save the model
model_name = "ppo-LunarLander-v2"
model.save(model_name)
# Out:
# Показано результат, скорочений до останніх рядків (5000).
# |    value_loss           | 16.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 740          |
# |    time_elapsed         | 1361         |
# |    total_timesteps      | 757760       |
# | train/                  |              |
# |    approx_kl            | 0.0012327607 |
# |    clip_fraction        | 0.0139       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.765       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.45         |
# |    n_updates            | 2956         |
# |    policy_gradient_loss | -0.000436    |
# |    value_loss           | 14.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 380          |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 741          |
# |    time_elapsed         | 1363         |
# |    total_timesteps      | 758784       |
# | train/                  |              |
# |    approx_kl            | 0.0037076892 |
# |    clip_fraction        | 0.0142       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.824       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.36         |
# |    n_updates            | 2960         |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 16.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 375         |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 742         |
# |    time_elapsed         | 1365        |
# |    total_timesteps      | 759808      |
# | train/                  |             |
# |    approx_kl            | 0.005965791 |
# |    clip_fraction        | 0.0461      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.667      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.81        |
# |    n_updates            | 2964        |
# |    policy_gradient_loss | -0.0043     |
# |    value_loss           | 12.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 376          |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 743          |
# |    time_elapsed         | 1366         |
# |    total_timesteps      | 760832       |
# | train/                  |              |
# |    approx_kl            | 0.0037484022 |
# |    clip_fraction        | 0.0234       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.818       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.89         |
# |    n_updates            | 2968         |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 18.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 377         |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 744         |
# |    time_elapsed         | 1368        |
# |    total_timesteps      | 761856      |
# | train/                  |             |
# |    approx_kl            | 0.002809722 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.683      |
# |    explained_variance   | 0.976       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15.5        |
# |    n_updates            | 2972        |
# |    policy_gradient_loss | -0.000947   |
# |    value_loss           | 33.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 745          |
# |    time_elapsed         | 1370         |
# |    total_timesteps      | 762880       |
# | train/                  |              |
# |    approx_kl            | 0.0018180031 |
# |    clip_fraction        | 0.00171      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.731       |
# |    explained_variance   | 0.656        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 390          |
# |    n_updates            | 2976         |
# |    policy_gradient_loss | -0.00232     |
# |    value_loss           | 917          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 371         |
# |    ep_rew_mean          | 244         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 746         |
# |    time_elapsed         | 1371        |
# |    total_timesteps      | 763904      |
# | train/                  |             |
# |    approx_kl            | 0.002599845 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.748      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.2        |
# |    n_updates            | 2980        |
# |    policy_gradient_loss | -0.000709   |
# |    value_loss           | 56.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 371          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 747          |
# |    time_elapsed         | 1374         |
# |    total_timesteps      | 764928       |
# | train/                  |              |
# |    approx_kl            | 0.0039681867 |
# |    clip_fraction        | 0.0288       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.754       |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.5         |
# |    n_updates            | 2984         |
# |    policy_gradient_loss | -0.00201     |
# |    value_loss           | 41.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 371          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 748          |
# |    time_elapsed         | 1376         |
# |    total_timesteps      | 765952       |
# | train/                  |              |
# |    approx_kl            | 0.0009338189 |
# |    clip_fraction        | 0.0161       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.716       |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15           |
# |    n_updates            | 2988         |
# |    policy_gradient_loss | -3.59e-05    |
# |    value_loss           | 22.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 370          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 749          |
# |    time_elapsed         | 1378         |
# |    total_timesteps      | 766976       |
# | train/                  |              |
# |    approx_kl            | 0.0042964257 |
# |    clip_fraction        | 0.0217       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.627        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 162          |
# |    n_updates            | 2992         |
# |    policy_gradient_loss | -0.00175     |
# |    value_loss           | 945          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 750          |
# |    time_elapsed         | 1379         |
# |    total_timesteps      | 768000       |
# | train/                  |              |
# |    approx_kl            | 0.0005723581 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.825       |
# |    explained_variance   | 0.662        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 353          |
# |    n_updates            | 2996         |
# |    policy_gradient_loss | -0.000515    |
# |    value_loss           | 943          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 751          |
# |    time_elapsed         | 1381         |
# |    total_timesteps      | 769024       |
# | train/                  |              |
# |    approx_kl            | 0.0039805714 |
# |    clip_fraction        | 0.0134       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.784       |
# |    explained_variance   | 0.942        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.46         |
# |    n_updates            | 3000         |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 40.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 372          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 752          |
# |    time_elapsed         | 1383         |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0003430145 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.788       |
# |    explained_variance   | 0.523        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1e+03        |
# |    n_updates            | 3004         |
# |    policy_gradient_loss | -2.95e-05    |
# |    value_loss           | 1.09e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 358          |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 753          |
# |    time_elapsed         | 1384         |
# |    total_timesteps      | 771072       |
# | train/                  |              |
# |    approx_kl            | 0.0009825868 |
# |    clip_fraction        | 0.00146      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.8         |
# |    n_updates            | 3008         |
# |    policy_gradient_loss | -0.000747    |
# |    value_loss           | 34           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 352          |
# |    ep_rew_mean          | 243          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 754          |
# |    time_elapsed         | 1386         |
# |    total_timesteps      | 772096       |
# | train/                  |              |
# |    approx_kl            | 0.0008383352 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.798       |
# |    explained_variance   | 0.601        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 400          |
# |    n_updates            | 3012         |
# |    policy_gradient_loss | 0.000163     |
# |    value_loss           | 952          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 755          |
# |    time_elapsed         | 1388         |
# |    total_timesteps      | 773120       |
# | train/                  |              |
# |    approx_kl            | 0.0033730268 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0.967        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.5         |
# |    n_updates            | 3016         |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 31.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 756          |
# |    time_elapsed         | 1391         |
# |    total_timesteps      | 774144       |
# | train/                  |              |
# |    approx_kl            | 0.0022336943 |
# |    clip_fraction        | 0.00781      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.727       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.65         |
# |    n_updates            | 3020         |
# |    policy_gradient_loss | -0.000723    |
# |    value_loss           | 20.5         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 345        |
# |    ep_rew_mean          | 245        |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 757        |
# |    time_elapsed         | 1392       |
# |    total_timesteps      | 775168     |
# | train/                  |            |
# |    approx_kl            | 0.00218503 |
# |    clip_fraction        | 0.0195     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.809     |
# |    explained_variance   | 0.639      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.17e+03   |
# |    n_updates            | 3024       |
# |    policy_gradient_loss | -5.28e-05  |
# |    value_loss           | 859        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 758         |
# |    time_elapsed         | 1394        |
# |    total_timesteps      | 776192      |
# | train/                  |             |
# |    approx_kl            | 0.004120437 |
# |    clip_fraction        | 0.0212      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.698      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.9        |
# |    n_updates            | 3028        |
# |    policy_gradient_loss | -0.00159    |
# |    value_loss           | 32.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 336          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 759          |
# |    time_elapsed         | 1396         |
# |    total_timesteps      | 777216       |
# | train/                  |              |
# |    approx_kl            | 0.0059901355 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.664       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.9         |
# |    n_updates            | 3032         |
# |    policy_gradient_loss | -0.004       |
# |    value_loss           | 24.5         |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 327       |
# |    ep_rew_mean          | 248       |
# | time/                   |           |
# |    fps                  | 556       |
# |    iterations           | 760       |
# |    time_elapsed         | 1397      |
# |    total_timesteps      | 778240    |
# | train/                  |           |
# |    approx_kl            | 0.0047656 |
# |    clip_fraction        | 0.0222    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.829    |
# |    explained_variance   | 0.972     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.94      |
# |    n_updates            | 3036      |
# |    policy_gradient_loss | -0.00294  |
# |    value_loss           | 22.8      |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 761          |
# |    time_elapsed         | 1399         |
# |    total_timesteps      | 779264       |
# | train/                  |              |
# |    approx_kl            | 0.0005535762 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.705       |
# |    explained_variance   | 0.666        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 410          |
# |    n_updates            | 3040         |
# |    policy_gradient_loss | -0.000745    |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 327          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 762          |
# |    time_elapsed         | 1401         |
# |    total_timesteps      | 780288       |
# | train/                  |              |
# |    approx_kl            | 0.0060492754 |
# |    clip_fraction        | 0.0601       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.77        |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.5         |
# |    n_updates            | 3044         |
# |    policy_gradient_loss | -0.0039      |
# |    value_loss           | 31.6         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 763         |
# |    time_elapsed         | 1403        |
# |    total_timesteps      | 781312      |
# | train/                  |             |
# |    approx_kl            | 0.008303873 |
# |    clip_fraction        | 0.0549      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.807      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.08        |
# |    n_updates            | 3048        |
# |    policy_gradient_loss | 0.000483    |
# |    value_loss           | 26.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 764          |
# |    time_elapsed         | 1405         |
# |    total_timesteps      | 782336       |
# | train/                  |              |
# |    approx_kl            | 0.0049724663 |
# |    clip_fraction        | 0.0295       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.726       |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.54         |
# |    n_updates            | 3052         |
# |    policy_gradient_loss | -0.00261     |
# |    value_loss           | 17.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 765          |
# |    time_elapsed         | 1407         |
# |    total_timesteps      | 783360       |
# | train/                  |              |
# |    approx_kl            | 0.0030138185 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.4         |
# |    n_updates            | 3056         |
# |    policy_gradient_loss | -0.000114    |
# |    value_loss           | 26.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 326         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 766         |
# |    time_elapsed         | 1408        |
# |    total_timesteps      | 784384      |
# | train/                  |             |
# |    approx_kl            | 0.006850344 |
# |    clip_fraction        | 0.0491      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.753      |
# |    explained_variance   | 0.983       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.79        |
# |    n_updates            | 3060        |
# |    policy_gradient_loss | -0.00475    |
# |    value_loss           | 15.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 767          |
# |    time_elapsed         | 1410         |
# |    total_timesteps      | 785408       |
# | train/                  |              |
# |    approx_kl            | 0.0073124035 |
# |    clip_fraction        | 0.0356       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.54         |
# |    n_updates            | 3064         |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 16.9         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 329        |
# |    ep_rew_mean          | 251        |
# | time/                   |            |
# |    fps                  | 556        |
# |    iterations           | 768        |
# |    time_elapsed         | 1412       |
# |    total_timesteps      | 786432     |
# | train/                  |            |
# |    approx_kl            | 0.00441965 |
# |    clip_fraction        | 0.0439     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.638     |
# |    explained_variance   | 0.995      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.77       |
# |    n_updates            | 3068       |
# |    policy_gradient_loss | -0.00117   |
# |    value_loss           | 8.22       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 769          |
# |    time_elapsed         | 1413         |
# |    total_timesteps      | 787456       |
# | train/                  |              |
# |    approx_kl            | 0.0010425507 |
# |    clip_fraction        | 0.00708      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.98         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.6         |
# |    n_updates            | 3072         |
# |    policy_gradient_loss | 0.00139      |
# |    value_loss           | 27.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 770          |
# |    time_elapsed         | 1415         |
# |    total_timesteps      | 788480       |
# | train/                  |              |
# |    approx_kl            | 0.0021589622 |
# |    clip_fraction        | 0.01         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.669       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.45         |
# |    n_updates            | 3076         |
# |    policy_gradient_loss | 0.000613     |
# |    value_loss           | 34.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 771          |
# |    time_elapsed         | 1418         |
# |    total_timesteps      | 789504       |
# | train/                  |              |
# |    approx_kl            | 0.0022763018 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 332          |
# |    n_updates            | 3080         |
# |    policy_gradient_loss | 0.00284      |
# |    value_loss           | 860          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 772         |
# |    time_elapsed         | 1420        |
# |    total_timesteps      | 790528      |
# | train/                  |             |
# |    approx_kl            | 0.002856566 |
# |    clip_fraction        | 0.0134      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.58        |
# |    n_updates            | 3084        |
# |    policy_gradient_loss | -0.000801   |
# |    value_loss           | 18.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 250          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 773          |
# |    time_elapsed         | 1421         |
# |    total_timesteps      | 791552       |
# | train/                  |              |
# |    approx_kl            | 0.0015206409 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.984        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 13.8         |
# |    n_updates            | 3088         |
# |    policy_gradient_loss | -0.00134     |
# |    value_loss           | 29.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 774          |
# |    time_elapsed         | 1423         |
# |    total_timesteps      | 792576       |
# | train/                  |              |
# |    approx_kl            | 0.0022066962 |
# |    clip_fraction        | 0.0173       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.819       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 172          |
# |    n_updates            | 3092         |
# |    policy_gradient_loss | -1.42e-05    |
# |    value_loss           | 927          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 324          |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 775          |
# |    time_elapsed         | 1425         |
# |    total_timesteps      | 793600       |
# | train/                  |              |
# |    approx_kl            | 0.0005620869 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.712       |
# |    explained_variance   | 0.704        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 84.6         |
# |    n_updates            | 3096         |
# |    policy_gradient_loss | -0.00112     |
# |    value_loss           | 533          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 324         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 776         |
# |    time_elapsed         | 1426        |
# |    total_timesteps      | 794624      |
# | train/                  |             |
# |    approx_kl            | 0.006410304 |
# |    clip_fraction        | 0.0352      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.971       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.1        |
# |    n_updates            | 3100        |
# |    policy_gradient_loss | -0.00219    |
# |    value_loss           | 35.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 323          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 557          |
# |    iterations           | 777          |
# |    time_elapsed         | 1428         |
# |    total_timesteps      | 795648       |
# | train/                  |              |
# |    approx_kl            | 0.0035546042 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.721       |
# |    explained_variance   | 0.699        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 455          |
# |    n_updates            | 3104         |
# |    policy_gradient_loss | -0.002       |
# |    value_loss           | 1.1e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 778         |
# |    time_elapsed         | 1430        |
# |    total_timesteps      | 796672      |
# | train/                  |             |
# |    approx_kl            | 0.004577957 |
# |    clip_fraction        | 0.0173      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.76       |
# |    explained_variance   | 0.978       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 15          |
# |    n_updates            | 3108        |
# |    policy_gradient_loss | -0.00185    |
# |    value_loss           | 32          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 779          |
# |    time_elapsed         | 1432         |
# |    total_timesteps      | 797696       |
# | train/                  |              |
# |    approx_kl            | 0.0025646323 |
# |    clip_fraction        | 0.0247       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.75        |
# |    explained_variance   | 0.985        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.26         |
# |    n_updates            | 3112         |
# |    policy_gradient_loss | -0.000918    |
# |    value_loss           | 18.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 326          |
# |    ep_rew_mean          | 249          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 780          |
# |    time_elapsed         | 1434         |
# |    total_timesteps      | 798720       |
# | train/                  |              |
# |    approx_kl            | 0.0035929023 |
# |    clip_fraction        | 0.0203       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | 0.989        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.1          |
# |    n_updates            | 3116         |
# |    policy_gradient_loss | -0.00263     |
# |    value_loss           | 12.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 329         |
# |    ep_rew_mean          | 251         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 781         |
# |    time_elapsed         | 1436        |
# |    total_timesteps      | 799744      |
# | train/                  |             |
# |    approx_kl            | 0.006113386 |
# |    clip_fraction        | 0.0583      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.68       |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28        |
# |    n_updates            | 3120        |
# |    policy_gradient_loss | -0.00308    |
# |    value_loss           | 17.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 328          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 782          |
# |    time_elapsed         | 1438         |
# |    total_timesteps      | 800768       |
# | train/                  |              |
# |    approx_kl            | 0.0024385038 |
# |    clip_fraction        | 0.0278       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.665       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.86         |
# |    n_updates            | 3124         |
# |    policy_gradient_loss | -0.000263    |
# |    value_loss           | 13.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 329          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 783          |
# |    time_elapsed         | 1439         |
# |    total_timesteps      | 801792       |
# | train/                  |              |
# |    approx_kl            | 0.0033401216 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.689       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.2          |
# |    n_updates            | 3128         |
# |    policy_gradient_loss | 0.000224     |
# |    value_loss           | 15.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 333          |
# |    ep_rew_mean          | 255          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 784          |
# |    time_elapsed         | 1441         |
# |    total_timesteps      | 802816       |
# | train/                  |              |
# |    approx_kl            | 0.0055559017 |
# |    clip_fraction        | 0.0449       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.647       |
# |    explained_variance   | 0.987        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.93         |
# |    n_updates            | 3132         |
# |    policy_gradient_loss | -0.00311     |
# |    value_loss           | 22.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 330         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 785         |
# |    time_elapsed         | 1443        |
# |    total_timesteps      | 803840      |
# | train/                  |             |
# |    approx_kl            | 0.003950118 |
# |    clip_fraction        | 0.0588      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.595      |
# |    explained_variance   | 0.996       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.6         |
# |    n_updates            | 3136        |
# |    policy_gradient_loss | -0.00461    |
# |    value_loss           | 7.42        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 332         |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 786         |
# |    time_elapsed         | 1445        |
# |    total_timesteps      | 804864      |
# | train/                  |             |
# |    approx_kl            | 0.006258091 |
# |    clip_fraction        | 0.0759      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.548       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 902         |
# |    n_updates            | 3140        |
# |    policy_gradient_loss | 0.000366    |
# |    value_loss           | 1.94e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 330          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 787          |
# |    time_elapsed         | 1447         |
# |    total_timesteps      | 805888       |
# | train/                  |              |
# |    approx_kl            | 0.0030961554 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.675       |
# |    explained_variance   | 0.988        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.5          |
# |    n_updates            | 3144         |
# |    policy_gradient_loss | -0.0024      |
# |    value_loss           | 18.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 788          |
# |    time_elapsed         | 1449         |
# |    total_timesteps      | 806912       |
# | train/                  |              |
# |    approx_kl            | 0.0003876568 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.782       |
# |    explained_variance   | 0.707        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 292          |
# |    n_updates            | 3148         |
# |    policy_gradient_loss | -0.000232    |
# |    value_loss           | 646          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 331           |
# |    ep_rew_mean          | 251           |
# | time/                   |               |
# |    fps                  | 556           |
# |    iterations           | 789           |
# |    time_elapsed         | 1451          |
# |    total_timesteps      | 807936        |
# | train/                  |               |
# |    approx_kl            | 0.00062033045 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.615        |
# |    explained_variance   | 0.953         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.24          |
# |    n_updates            | 3152          |
# |    policy_gradient_loss | -0.000404     |
# |    value_loss           | 51.7          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 790          |
# |    time_elapsed         | 1452         |
# |    total_timesteps      | 808960       |
# | train/                  |              |
# |    approx_kl            | 0.0009996889 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.73        |
# |    explained_variance   | 0.659        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 379          |
# |    n_updates            | 3156         |
# |    policy_gradient_loss | -0.00126     |
# |    value_loss           | 807          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 791          |
# |    time_elapsed         | 1454         |
# |    total_timesteps      | 809984       |
# | train/                  |              |
# |    approx_kl            | 0.0061055147 |
# |    clip_fraction        | 0.041        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.722       |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.61         |
# |    n_updates            | 3160         |
# |    policy_gradient_loss | -0.00295     |
# |    value_loss           | 28.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 337          |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 792          |
# |    time_elapsed         | 1456         |
# |    total_timesteps      | 811008       |
# | train/                  |              |
# |    approx_kl            | 0.0020401506 |
# |    clip_fraction        | 0.00659      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.69        |
# |    explained_variance   | 0.978        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.16         |
# |    n_updates            | 3164         |
# |    policy_gradient_loss | -0.000571    |
# |    value_loss           | 25.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 337         |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 793         |
# |    time_elapsed         | 1457        |
# ...
# | time/                   |               |
# |    fps                  | 556           |
# |    iterations           | 960           |
# |    time_elapsed         | 1766          |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 5.4106175e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.775        |
# |    explained_variance   | 0.799         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 260           |
# |    n_updates            | 3836          |
# |    policy_gradient_loss | 0.000107      |
# |    value_loss           | 854           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 303           |
# |    ep_rew_mean          | 216           |
# | time/                   |               |
# |    fps                  | 556           |
# |    iterations           | 961           |
# |    time_elapsed         | 1767          |
# |    total_timesteps      | 984064        |
# | train/                  |               |
# |    approx_kl            | 0.00040356792 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.697        |
# |    explained_variance   | 0.871         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 33.9          |
# |    n_updates            | 3840          |
# |    policy_gradient_loss | -0.000154     |
# |    value_loss           | 119           |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 298         |
# |    ep_rew_mean          | 216         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 962         |
# |    time_elapsed         | 1769        |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.008468605 |
# |    clip_fraction        | 0.0779      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.979       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.2        |
# |    n_updates            | 3844        |
# |    policy_gradient_loss | -0.00518    |
# |    value_loss           | 25          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 298          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 963          |
# |    time_elapsed         | 1772         |
# |    total_timesteps      | 986112       |
# | train/                  |              |
# |    approx_kl            | 0.0017808214 |
# |    clip_fraction        | 0.0022       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.698       |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 486          |
# |    n_updates            | 3848         |
# |    policy_gradient_loss | -0.00074     |
# |    value_loss           | 694          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 295          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 964          |
# |    time_elapsed         | 1774         |
# |    total_timesteps      | 987136       |
# | train/                  |              |
# |    approx_kl            | 0.0009055408 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.768       |
# |    explained_variance   | 0.731        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 134          |
# |    n_updates            | 3852         |
# |    policy_gradient_loss | -0.000965    |
# |    value_loss           | 742          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 298           |
# |    ep_rew_mean          | 213           |
# | time/                   |               |
# |    fps                  | 556           |
# |    iterations           | 965           |
# |    time_elapsed         | 1775          |
# |    total_timesteps      | 988160        |
# | train/                  |               |
# |    approx_kl            | 0.00012558285 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.72         |
# |    explained_variance   | 0.757         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 99.4          |
# |    n_updates            | 3856          |
# |    policy_gradient_loss | -0.000387     |
# |    value_loss           | 583           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 306          |
# |    ep_rew_mean          | 213          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 966          |
# |    time_elapsed         | 1777         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 0.0017409364 |
# |    clip_fraction        | 0.000244     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.743       |
# |    explained_variance   | 0.754        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 315          |
# |    n_updates            | 3860         |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 643          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 307          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 967          |
# |    time_elapsed         | 1779         |
# |    total_timesteps      | 990208       |
# | train/                  |              |
# |    approx_kl            | 0.0030482821 |
# |    clip_fraction        | 0.00903      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.856       |
# |    explained_variance   | 0.962        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.92         |
# |    n_updates            | 3864         |
# |    policy_gradient_loss | -0.00276     |
# |    value_loss           | 47.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 308          |
# |    ep_rew_mean          | 214          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 968          |
# |    time_elapsed         | 1780         |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0029879736 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.746       |
# |    explained_variance   | 0.867        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 11.3         |
# |    n_updates            | 3868         |
# |    policy_gradient_loss | -0.00119     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 316          |
# |    ep_rew_mean          | 215          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 969          |
# |    time_elapsed         | 1782         |
# |    total_timesteps      | 992256       |
# | train/                  |              |
# |    approx_kl            | 0.0009049319 |
# |    clip_fraction        | 0.000977     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.715       |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 55.4         |
# |    n_updates            | 3872         |
# |    policy_gradient_loss | -0.00057     |
# |    value_loss           | 127          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 323         |
# |    ep_rew_mean          | 215         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 970         |
# |    time_elapsed         | 1784        |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.008308432 |
# |    clip_fraction        | 0.0808      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.55        |
# |    n_updates            | 3876        |
# |    policy_gradient_loss | -0.00546    |
# |    value_loss           | 14.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 327         |
# |    ep_rew_mean          | 218         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 971         |
# |    time_elapsed         | 1787        |
# |    total_timesteps      | 994304      |
# | train/                  |             |
# |    approx_kl            | 0.003513021 |
# |    clip_fraction        | 0.0217      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.566      |
# |    explained_variance   | 0.969       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.6        |
# |    n_updates            | 3880        |
# |    policy_gradient_loss | -0.00104    |
# |    value_loss           | 36.6        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 331          |
# |    ep_rew_mean          | 220          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 972          |
# |    time_elapsed         | 1788         |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0014784212 |
# |    clip_fraction        | 0.00732      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.644       |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 391          |
# |    n_updates            | 3884         |
# |    policy_gradient_loss | 0.000146     |
# |    value_loss           | 658          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 334         |
# |    ep_rew_mean          | 219         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 973         |
# |    time_elapsed         | 1790        |
# |    total_timesteps      | 996352      |
# | train/                  |             |
# |    approx_kl            | 0.002883001 |
# |    clip_fraction        | 0.0171      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.46        |
# |    n_updates            | 3888        |
# |    policy_gradient_loss | -0.00162    |
# |    value_loss           | 37.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 338         |
# |    ep_rew_mean          | 221         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 974         |
# |    time_elapsed         | 1792        |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.008358001 |
# |    clip_fraction        | 0.0845      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.613      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 3892        |
# |    policy_gradient_loss | -0.00708    |
# |    value_loss           | 50.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 339         |
# |    ep_rew_mean          | 226         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 975         |
# |    time_elapsed         | 1793        |
# |    total_timesteps      | 998400      |
# | train/                  |             |
# |    approx_kl            | 0.005050132 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.641      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.6        |
# |    n_updates            | 3896        |
# |    policy_gradient_loss | -0.000739   |
# |    value_loss           | 90.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 347         |
# |    ep_rew_mean          | 227         |
# | time/                   |             |
# |    fps                  | 556         |
# |    iterations           | 976         |
# |    time_elapsed         | 1795        |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.009434365 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.673      |
# |    explained_variance   | 0.988       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.18        |
# |    n_updates            | 3900        |
# |    policy_gradient_loss | -0.000585   |
# |    value_loss           | 15.5        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 348          |
# |    ep_rew_mean          | 229          |
# | time/                   |              |
# |    fps                  | 556          |
# |    iterations           | 977          |
# |    time_elapsed         | 1797         |
# |    total_timesteps      | 1000448      |
# | train/                  |              |
# |    approx_kl            | 0.0029562083 |
# |    clip_fraction        | 0.0408       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.902       |
# |    explained_variance   | 0.966        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.14         |
# |    n_updates            | 3904         |
# |    policy_gradient_loss | 4.03e-06     |
# |    value_loss           | 19.4         |
# ------------------------------------------

# %%
# @title
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=225.57 +/- 102.56565931822581

# %%
evaluate_policy(model, env, n_eval_episodes=10, render=True)
env.close()
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py:208: UserWarning: You tried to call render() but no `render_mode` was passed to the env constructor.
#   warnings.warn("You tried to call render() but no `render_mode` was passed to the env constructor.")

# %%
 model.save("LunarAI")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
